# %%
# %pylab inline

import pickle
import itertools

import numpy as np
from PIL import Image, ImageDraw

from imagetools import (path_to_img_array
                        , pick_colors
                        , show_key_colors
                        , avg_rgb)
from metadatatools import filter_by_genre
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
f = open('genres.pkl', 'rb')
genres = pickle.load(f)
f.close()

# %%
allGenres = set(itertools.chain.from_iterable(genres.values()))

# %%
for genre in allGenres:
    print(genre, len(filter_by_genre(genres, genre)))
# Out:
# Musical 11
# Comedy 164
# Family 38
# Biography 59
# Sci-Fi 55
# Romance 59
# News 1
# Horror 69
# Fantasy 37
# Action 93
# Mystery 38
# History 37
# Drama 320
# Western 7
# Thriller 140
# Sport 15
# Animation 33
# War 27
# Adventure 65
# Crime 50
# Music 20
# Documentary 126

# %% [markdown]
# Testing Avg RGB function

# %%
path = r"posters\Mother.png"

pic = Image.open(path)
picVec = np.array(pic)

print(avg_rgb(picVec))
pic
# Out:
# (104, 79, 65)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x210 at 0x9B44C88>

# %%
Image.new('RGB', (100, 100), color=avg_rgb(picVec))
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x9B44828>

# %%
base = r'posters/'

horror = filter_by_genre(genres, 'War')
avgColors = []

for movie in horror:
    path = base + movie + '.png'
    pic = Image.open(path)
    picVec = np.array(pic)
    avgColors.append(avg_rgb(picVec))

avgColors = np.array(avgColors)
allAvg = tuple([int(x) for x in np.average(avgColors, axis=0)])
Image.new('RGB', (100, 100), color=allAvg)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x9B47C50>

# %%
path = r"posters\SpiderMan Homecoming.png"
pic = Image.open(path)
picVec = np.array(pic)
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x210 at 0x9B35E10>

# %%
Image.new('RGB', (100, 100), color=avg_rgb(picVec))
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x9AA25C0>

# %%
show_key_colors(pick_colors(picVec, 5))
# Out:
# (31, 36, 45)
# (114, 163, 199)
# (141, 17, 36)
# (189, 209, 225)
# (83, 96, 114)
# <PIL.Image.Image image mode=RGBA size=500x100 at 0x9B98BE0>

# %% [markdown]
# ### Building out a list of Horror movies for later blog

# %%
horrorMovies = filter_by_genre(genres, 'Horror')

# %%
import csv

# %%
csv.writer?

# %%
with open('../Horror\ Movies\ 2017/horror.csv', 'w') as f:
    writer = csv.writer(f)
    for movie in horrorMovies:
        writer.writerow([movie])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-48-84b01a72c242> in <module>()
# ----> 1 with open('../Horror\ Movies\ 2017/horror.csv', 'w') as f:
#       2     writer = csv.writer(f)
#       3     for movie in horrorMovies:
#       4         writer.writerow([movie])
#
# FileNotFoundError: [Errno 2] No such file or directory: '../Horror\\ Movies\\ 2017/horror.csv'
