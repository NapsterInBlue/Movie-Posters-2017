# %% [markdown]
# [Movie Poster Website](http://www.wildaboutmovies.com/2017_movies/)

# %% [markdown]
# PIL (Python Image Library)
# Numpy
# Matplotlib (Pylab)
# KMeans - SciPy

# %% [markdown]
# ## Working with Images with PIL

# %%
from PIL import Image, ImageDraw

# %%
baby = Image.open('images/babydriver.png')
print(baby.size)
baby
# Out:
# (200, 300)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x300 at 0x7BA3E48>

# %% [markdown]
# What if you want to draw overtop of your image?

# %%
draw = ImageDraw.Draw(baby)
draw.rectangle([(0, 0), (50, 50)], fill=(0, 0, 0))
draw.line([(200, 200), (100, 100)], fill=(0, 0, 200), width=6)
baby
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x300 at 0x7BA3E48>

# %% [markdown]
# What if we wanna tile the image?

# %%
x, y = baby.size
xsteps = x / 50
ysteps = y / 50

# %%
for xstep in range(int(xsteps)):
    for ystep in range(int(ysteps)):
        if xstep % 2 == 1 and ystep % 2 == 1:
            draw.rectangle([(xstep*50, ystep*50), ((xstep+1)*50, (ystep+1)*50)], fill=(0, 0, 0))
        if xstep % 2 == 0 and ystep % 2 == 0:
            draw.rectangle([(xstep*50, ystep*50), ((xstep+1)*50, (ystep+1)*50)], fill=(0, 0, 0))

baby
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x300 at 0x7BA3E48>

# %% [markdown]
# What about creating an image from scratch?

# %%
blackBox = Image.new('RGBA', (100, 100), color=(0, 0, 0))
blackBox
# Out:
# <PIL.Image.Image image mode=RGBA size=100x100 at 0x7BC8EB8>

# %% [markdown]
# ##  Using Numpy with Images

# %%
import numpy as np

# %% [markdown]
# Every pixel is an RGB value. And the image is made up of Width x Height pixels

# %%
Image.open('images/xx.png')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x300 at 0x7BC8C88>

# %%
img = Image.open('images/xx.png')

# %%
vec = np.array(img)
vec.shape
# Out:
# (300, 200, 3)

# %% [markdown]
# Manipulating the dimensions of numpy array

# %%
vec.size
# Out:
# 180000

# %%
vec.reshape(60000, 3)
# Out:
# array([[19,  0, 28],
#        [17,  4, 30],
#        [ 7,  4, 25],
#        ...,
#        [26, 11, 34],
#        [27,  9, 33],
#        [24,  4, 29]], dtype=uint8)

# %%
tyler = vec.ravel()[:100]

# %%
vec.reshape(-1, 3).shape
# Out:
# (60000, 3)

# %% [markdown]
# ## Clustering

# %%
# %pylab inline

from colorpicker import (path_to_img_array
                         , pick_colors
                         , show_key_colors)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# C:\Users\nhounshell\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\magics\pylab.py:160: UserWarning: pylab import has clobbered these variables: ['draw']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
from IPython.display import HTML

# Youtube
HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/IuRb3y8qKX4" frameborder="0" gesture="media" allow="encrypted-media" allowfullscreen></iframe>')
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/IuRb3y8qKX4" frameborder="0" gesture="media" allow="encrypted-media" allowfullscreen></iframe>

# %%
img.reshape(-1, 3)
# Out:
# array([[19,  0, 28],
#        [17,  4, 30],
#        [ 7,  4, 25],
#        ...,
#        [26, 11, 34],
#        [27,  9, 33],
#        [24,  4, 29]], dtype=uint8)

# %%
Image.open(path)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x300 at 0xC6A0F98>

# %%
path = 'images/xx.png'

img = path_to_img_array(path)
plt.imshow(show_key_colors(pick_colors(img, 5)))
# Out:
# (12, 2, 27)
# (0, 0) (100, 100)
# (145, 14, 55)
# (100, 0) (200, 200)
# (64, 11, 38)
# (200, 0) (300, 300)
# (207, 11, 70)
# (300, 0) (400, 400)
# (125, 119, 133)
# (400, 0) (500, 500)

# %%
# %pylab inline

import numpy as np
from sklearn.cluster import KMeans
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd

# %%
import seaborn.apionly as sns
iris = sns.load_dataset('iris')
print(iris.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# C:\Users\nhounshell\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\apionly.py:6: UserWarning: As seaborn no longer sets a default style on import, the seaborn.apionly module is deprecated. It will be removed in a future version.
#   warnings.warn(msg, UserWarning)

# %%
trimmedData = iris[['sepal_length', 'sepal_width']]

plt.scatter(x=trimmedData['sepal_length'], y=trimmedData['sepal_width'])

# %%
model = KMeans(n_clusters=3).fit(trimmedData)
trimmedData['label']= model.labels_
# Out:
# C:\Users\nhounshell\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
plt.scatter(x=trimmedData['sepal_length'], y=trimmedData['sepal_width'], c=trimmedData['label'])

# %% [markdown]
# ## Altogether

# %%
from colorpicker import (path_to_img_array
                         , pick_colors
                         , show_key_colors)

# %%
path = 'images/xx.png'
Image.open(path)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x300 at 0xEFC2E48>

# %%
img = path_to_img_array(path)
plt.imshow(show_key_colors(pick_colors(img, 8)))
# Out:
# (26, 3, 28)
# (0, 0) (100, 100)
# (178, 15, 64)
# (100, 0) (200, 200)
# (212, 10, 71)
# (200, 0) (300, 300)
# (126, 12, 49)
# (300, 0) (400, 400)
# (151, 147, 160)
# (400, 0) (500, 500)
# (6, 1, 26)
# (500, 0) (600, 600)
# (69, 10, 37)
# (600, 0) (700, 700)
# (86, 77, 92)
# (700, 0) (800, 800)

# %%
path = 'images/idiotas.png'
img = Image.open(path)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x300 at 0xEDA69B0>

# %%
img = path_to_img_array(path)
plt.imshow(show_key_colors(pick_colors(img, 8)))
# Out:
# (237, 232, 227)
# (0, 0) (100, 100)
# (81, 111, 99)
# (100, 0) (200, 200)
# (234, 180, 28)
# (200, 0) (300, 300)
# (37, 29, 28)
# (300, 0) (400, 400)
# (215, 168, 148)
# (400, 0) (500, 500)
# (105, 154, 194)
# (500, 0) (600, 600)
# (175, 75, 94)
# (600, 0) (700, 700)
# (6, 121, 189)
# (700, 0) (800, 800)

# %%
img = path_to_img_array(path)
plt.imshow(show_key_colors(pick_colors(img, 2)))
# Out:
# (31, 100, 139)
# (0, 0) (100, 100)
# (204, 159, 131)
# (100, 0) (200, 200)

# %%
path = 'images/wes.png'

img = path_to_img_array(path)
plt.imshow(show_key_colors(pick_colors(img, 5)))
# Out:
# (158, 85, 19)
# (0, 0) (100, 100)
# (161, 111, 88)
# (100, 0) (200, 200)
# (48, 32, 33)
# (200, 0) (300, 300)
# (210, 161, 141)
# (300, 0) (400, 400)
# (110, 60, 49)
# (400, 0) (500, 500)

# %%
img.shape[0] * img.shape[1]
# Out:
# 518400

# %%
path = 'images/bigWes.png'
img = Image.open(path)
img.size[0] * img.size[1]
# Out:
# 10050304

# %%
path = 'images/zoo.png'

img = path_to_img_array(path)
plt.imshow(show_key_colors(pick_colors(img, 5)))
# Out:
# (52, 45, 48)
# (0, 0) (100, 100)
# (171, 154, 142)
# (100, 0) (200, 200)
# (95, 80, 73)
# (200, 0) (300, 300)
# (209, 202, 199)
# (300, 0) (400, 400)
# (132, 114, 105)
# (400, 0) (500, 500)

# %%
path = 'images/grainyZoo.png'

img = path_to_img_array(path)
plt.imshow(show_key_colors(pick_colors(img, 5)))
# Out:
# (93, 79, 74)
# (0, 0) (100, 100)
# (159, 141, 127)
# (100, 0) (200, 200)
# (125, 109, 101)
# (200, 0) (300, 300)
# (51, 46, 52)
# (300, 0) (400, 400)
# (183, 177, 180)
# (400, 0) (500, 500)
